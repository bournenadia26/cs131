# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import keras
import tensorflow as tf
from sklearn.model_selection import KFold
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential, Model
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score

# %%
train_df = pd.read_csv("https://raw.githubusercontent.com/bournenadia26/cs131/refs/heads/main/train_midterm.csv")
test_df = pd.read_csv("https://raw.githubusercontent.com/bournenadia26/cs131/refs/heads/main/test_midterm.csv")

# convert from df to np arr
X_train = train_df.drop(columns=['label']).to_numpy()
y_train = train_df['label'].to_numpy()
X_test = test_df.drop(columns=['label']).to_numpy()
y_test = test_df['label'].to_numpy()

# build function
def build(learning_rate):

  layers = [tf.keras.layers.Input(shape=(X_train.shape[1],))]
  layers.append(tf.keras.layers.Dense(1, activation='sigmoid', kernel_initializer=tf.zeros_initializer()))

  model = tf.keras.models.Sequential(
      layers=layers,
  )

  model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
  return model

avg_loss_list = []
kfold = KFold(n_splits=5, shuffle=True, random_state=1)

# values to test
eta_list = [0.1, 0.01, 0.001]
num_of_epochs = [50, 200, 500]

for eta in eta_list:  # to test values
  for epochs in num_of_epochs:

    final_val_loss_list = []
    final_train_loss_list = []

    print("------------------------------------------------")
    print(f"\nLearning Rate: {eta}, Epoch Count: {epochs}\n")
    print("------------------------------------------------\n")

    for train_idx, val_idx in kfold.split(X_train):

      model = build(eta)  # run our build function

      history = model.fit(
        X_train[train_idx], # X
        y_train[train_idx], # y
        validation_data=(X_train[val_idx], y_train[val_idx]), # give val data specifically
        epochs=epochs,
        batch_size=8,
        verbose=0,
      )

      #save final loss of iteration
      final_val_loss = history.history['val_loss'][-1]
      final_train_loss = history.history['loss'][-1]

      print(f"Final Validation Loss: {final_val_loss}")
      print(f"Final Train Loss: {final_train_loss}\n")

      final_val_loss_list.append(final_val_loss)
      final_train_loss_list.append(final_train_loss)

    # calculate avg
    avg_val_loss = np.mean(final_val_loss_list)
    avg_train_loss = np.mean(final_train_loss_list)
    avg_loss_list.append((eta, epochs, avg_val_loss, avg_train_loss))


best_val_loss = float('inf')
best_train_loss = 0
best_eta = 0
best_num_of_epochs = 0

print("\n------------------------------------------------")
for eta, epochs, avg_val_loss, avg_train_loss in avg_loss_list:
    print(f"Learning Rate: {eta}, Number of Epochs: {epochs}, Avg Val Loss: {avg_val_loss}, Avg Train Loss: {avg_train_loss}")

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_train_loss = avg_train_loss
        best_eta = eta
        best_num_of_epochs = epochs

print("------------------------------------------------")
print(f"\nBest Validation Loss: {best_val_loss}, Best Training Loss: {best_train_loss} with Learning Rate: {best_eta}, Number of Epochs: {best_num_of_epochs}\n")
print("------------------------------------------------\n")

# run it again for the final train loss
best_model = build(best_eta)
best_history = best_model.fit(
        X_train, # X
        y_train, # y
        epochs=best_num_of_epochs,
        batch_size=8,
        verbose=0,
      )

final_train_loss = best_history.history['loss'][-1]
print(f"Final Train Loss: {final_train_loss}\n")
print("------------------------------------------------\n")

# test data
test_loss = best_model.evaluate(X_test, y_test, verbose=0)[0] # use train data to evaluate test data
y_hat_pred = best_model.predict(X_test)
y_hat = (y_hat_pred >= 0.5).astype(int) #given prediction rule
test_accuracy = accuracy_score(y_test, y_hat)
test_f1 = f1_score(y_test, y_hat)

print("------------------------------------------------")
print(f"\nTest Loss: {test_loss}, Accuracy: {test_accuracy}, F1 Score: {test_f1}\n")
print("------------------------------------------------\n")

# plotting
plt.plot(best_history.history['loss'], label='Training Loss')
plt.yscale('log')
plt.title(f'Best Model : Learning Rate: {best_eta}, Number of Epochs: {best_num_of_epochs})')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ------------------------------------------------
#
# Learning Rate: 0.1, Epoch Count: 50
#
# ------------------------------------------------
#
# Final Validation Loss: 0.08075889945030212
# Final Train Loss: 0.03257625177502632
#
# Final Validation Loss: 0.09268978983163834
# Final Train Loss: 0.03303126245737076
#
# Final Validation Loss: 0.053566936403512955
# Final Train Loss: 0.034080587327480316
#
# Final Validation Loss: 0.06330473721027374
# Final Train Loss: 0.03362472355365753
#
# Final Validation Loss: 0.06464937329292297
# Final Train Loss: 0.033246591687202454
#
# ------------------------------------------------
#
# Learning Rate: 0.1, Epoch Count: 200
#
# ------------------------------------------------
#
# Final Validation Loss: 0.07894542813301086
# Final Train Loss: 0.013808151707053185
#
# Final Validation Loss: 0.0993945449590683
# Final Train Loss: 0.014083921909332275
#
# Final Validation Loss: 0.04600244015455246
# Final Train Loss: 0.013536046259105206
#
# Final Validation Loss: 0.06170742213726044
# Final Train Loss: 0.01365343201905489
#
# Final Validation Loss: 0.06394699960947037
# Final Train Loss: 0.013176419772207737
#
# ------------------------------------------------
#
# Learning Rate: 0.1, Epoch Count: 500
#
# ------------------------------------------------
#
# Final Validation Loss: 0.08423185348510742
# Final Train Loss: 0.00852251797914505
#
# Final Validation Loss: 0.11332591623067856
# Final Train Loss: 0.008461789228022099
#
# Final Validation Loss: 0.04698687046766281
# Final Train Loss: 0.007378382608294487
#
# Final Validation Loss: 0.06746585667133331
# Final Train Loss: 0.008199417032301426
#
# Final Validation Loss: 0.07198183238506317
# Final Train Loss: 0.0072074937634170055
#
# ------------------------------------------------
#
# Learning Rate: 0.01, Epoch Count: 50
#
# ------------------------------------------------
#
# Final Validation Loss: 0.12579768896102905
# Final Train Loss: 0.09490380436182022
#
# Final Validation Loss: 0.1279297173023224
# Final Train Loss: 0.0929497703909874
#
# Final Validation Loss: 0.09414657950401306
# Final Train Loss: 0.09918642044067383
#
# Final Validation Loss: 0.10029827058315277
# Final Train Loss: 0.09830997884273529
#
# Final Validation Loss: 0.10243485122919083
# Final Train Loss: 0.09742388874292374
#
# ------------------------------------------------
#
# Learning Rate: 0.01, Epoch Count: 200
#
# ------------------------------------------------
#
# Final Validation Loss: 0.09077110141515732
# Final Train Loss: 0.05244304612278938
#
# Final Validation Loss: 0.09970463812351227
# Final Train Loss: 0.052159182727336884
#
# Final Validation Loss: 0.06375909596681595
# Final Train Loss: 0.055053383111953735
#
# Final Validation Loss: 0.0725153386592865
# Final Train Loss: 0.05467213690280914
#
# Final Validation Loss: 0.07340986281633377
# Final Train Loss: 0.05401107668876648
#
# ------------------------------------------------
#
# Learning Rate: 0.01, Epoch Count: 500
#
# ------------------------------------------------
#
# Final Validation Loss: 0.0808802917599678
# Final Train Loss: 0.032261043787002563
#
# Final Validation Loss: 0.09312482923269272
# Final Train Loss: 0.03272855281829834
#
# Final Validation Loss: 0.053639523684978485
# Final Train Loss: 0.03373105823993683
#
# Final Validation Loss: 0.06338956207036972
# Final Train Loss: 0.03329269215464592
#
# Final Validation Loss: 0.06465426087379456
# Final Train Loss: 0.03290246054530144
#
# ------------------------------------------------
#
# Learning Rate: 0.001, Epoch Count: 50
#
# ------------------------------------------------
#
# Final Validation Loss: 0.2922004163265228
# Final Train Loss: 0.24421952664852142
#
# Final Validation Loss: 0.26723557710647583
# Final Train Loss: 0.24587970972061157
#
# Final Validation Loss: 0.24239926040172577
# Final Train Loss: 0.25252747535705566
#
# Final Validation Loss: 0.2334400862455368
# Final Train Loss: 0.2525024116039276
#
# Final Validation Loss: 0.23435159027576447
# Final Train Loss: 0.25046712160110474
#
# ------------------------------------------------
#
# Learning Rate: 0.001, Epoch Count: 200
#
# ------------------------------------------------
#
# Final Validation Loss: 0.17209088802337646
# Final Train Loss: 0.1380377858877182
#
# Final Validation Loss: 0.16523398458957672
# Final Train Loss: 0.13627973198890686
#
# Final Validation Loss: 0.1344081312417984
# Final Train Loss: 0.14365799725055695
#
# Final Validation Loss: 0.1367211937904358
# Final Train Loss: 0.14251281321048737
#
# Final Validation Loss: 0.13982926309108734
# Final Train Loss: 0.14119283854961395
#
# ------------------------------------------------
#
# Learning Rate: 0.001, Epoch Count: 500
#
# ------------------------------------------------
#
# Final Validation Loss: 0.1258818805217743
# Final Train Loss: 0.0944652408361435
#
# Final Validation Loss: 0.1279713213443756
# Final Train Loss: 0.09253054857254028
#
# Final Validation Loss: 0.09417691826820374
# Final Train Loss: 0.0987236499786377
#
# Final Validation Loss: 0.10031947493553162
# Final Train Loss: 0.09786229580640793
#
# Final Validation Loss: 0.10249883681535721
# Final Train Loss: 0.09698086231946945
#
#
# ------------------------------------------------
# Learning Rate: 0.1, Number of Epochs: 50, Avg Val Loss: 0.07099394723773003, Avg Train Loss: 0.033311883360147475
# Learning Rate: 0.1, Number of Epochs: 200, Avg Val Loss: 0.06999936699867249, Avg Train Loss: 0.013651594333350659
# Learning Rate: 0.1, Number of Epochs: 500, Avg Val Loss: 0.07679846584796905, Avg Train Loss: 0.007953920122236013
# Learning Rate: 0.01, Number of Epochs: 50, Avg Val Loss: 0.11012142151594162, Avg Train Loss: 0.09655477255582809
# Learning Rate: 0.01, Number of Epochs: 200, Avg Val Loss: 0.08003200739622116, Avg Train Loss: 0.053667765110731125
# Learning Rate: 0.01, Number of Epochs: 500, Avg Val Loss: 0.07113769352436065, Avg Train Loss: 0.03298316150903702
# Learning Rate: 0.001, Number of Epochs: 50, Avg Val Loss: 0.25392538607120513, Avg Train Loss: 0.2491192489862442
# Learning Rate: 0.001, Number of Epochs: 200, Avg Val Loss: 0.14965669214725494, Avg Train Loss: 0.14033623337745665
# Learning Rate: 0.001, Number of Epochs: 500, Avg Val Loss: 0.11016968637704849, Avg Train Loss: 0.09611251950263977
# ------------------------------------------------
#
# Best Validation Loss: 0.06999936699867249, Best Training Loss: 0.013651594333350659 with Learning Rate: 0.1, Number of Epochs: 200
#
# ------------------------------------------------
#
# Final Train Loss: 0.013722535222768784
#
# ------------------------------------------------
#
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ------------------------------------------------
#
# Test Loss: 0.057136207818984985, Accuracy: 0.9829596412556054, F1 Score: 0.9381107491856677
#
# ------------------------------------------------

# %%
train_df = pd.read_csv("https://raw.githubusercontent.com/bournenadia26/cs131/refs/heads/main/train_midterm.csv")
test_df = pd.read_csv("https://raw.githubusercontent.com/bournenadia26/cs131/refs/heads/main/test_midterm.csv")

# from df to numpy arr
X_train = train_df.drop(columns=['label']).to_numpy()
y_train = train_df['label'].to_numpy()
X_test = test_df.drop(columns=['label']).to_numpy()
y_test = test_df['label'].to_numpy()

avg_loss_list = []
kfold = KFold(n_splits=5, shuffle=True, random_state=1)

# values to test
eta_list = [0.1, 0.01, 0.001]
num_of_epochs = [50, 200, 500]

for eta in eta_list:
    for epochs in num_of_epochs:
        val_loss_list = []
        train_loss_list = []

        print("------------------------------------------------")
        print(f"\nLearning Rate: {eta}, Epoch Count: {epochs}\n")
        print("------------------------------------------------\n")

        for train_idx, val_idx in kfold.split(X_train):
            X_train_fold, y_train_fold = X_train[train_idx], y_train[train_idx]
            X_val_fold, y_val_fold = X_train[val_idx], y_train[val_idx]

            w = np.zeros(X_train.shape[1])

            for epoch in range(epochs):
                for i in range(X_train_fold.shape[0]):
                    y_hat = 1 / (1 + np.exp(-np.dot(X_train_fold[i], w)))
                    gradient = (y_hat - y_train_fold[i]) * X_train_fold[i]
                    w -= eta * gradient

            y_train_pred = 1 / (1 + np.exp(-np.dot(X_train_fold, w)))
            y_val_pred = 1 / (1 + np.exp(-np.dot(X_val_fold, w)))
            train_loss = -np.mean(y_train_fold * np.log(y_train_pred + 1e-9) + (1 - y_train_fold) * np.log(1 - y_train_pred + 1e-9))
            val_loss = -np.mean(y_val_fold * np.log(y_val_pred + 1e-9) + (1 - y_val_fold) * np.log(1 - y_val_pred + 1e-9))

            train_loss_list.append(train_loss)
            val_loss_list.append(val_loss)

            print(f"Fold Train Loss: {train_loss:.4f}, Fold Val Loss: {val_loss:.4f}")

        avg_train_loss = np.mean(train_loss_list)
        avg_val_loss = np.mean(val_loss_list)
        avg_loss_list.append((eta, epochs, avg_train_loss, avg_val_loss))

        print(f"Avg Train Loss: {avg_train_loss:.4f}, Avg Val Loss: {avg_val_loss:.4f}\n")

best_val_loss = float('inf')
best_train_loss = 0
best_eta = 0
best_num_of_epochs = 0

print("\n------------------------------------------------")
for eta, epochs, avg_train_loss, avg_val_loss in avg_loss_list:
    print(f"Learning Rate: {eta}, Number of Epochs: {epochs}, Avg Train Loss: {avg_train_loss}, Avg Val Loss: {avg_val_loss}")

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_train_loss = avg_train_loss
        best_eta = eta
        best_num_of_epochs = epochs

print("------------------------------------------------")
print(f"\nBest Validation Loss: {best_val_loss}, Best Training Loss: {best_train_loss} with Learning Rate: {best_eta}, Number of Epochs: {best_num_of_epochs}\n")
print("------------------------------------------------\n")

# retrain on test
w = np.zeros(X_train.shape[1])
best_loss_history = []

for epoch in range(best_num_of_epochs):
    epoch_loss = []
    for i in range(X_train.shape[0]):
        y_hat = 1 / (1 + np.exp(-np.dot(X_train[i], w)))
        gradient = (y_hat - y_train[i]) * X_train[i]
        w -= best_eta * gradient

        loss = -np.mean(y_train[i] * np.log(y_hat + 1e-9) + (1 - y_train[i]) * np.log(1 - y_hat + 1e-9))
        epoch_loss.append(loss)

    best_loss_history.append(np.mean(epoch_loss))

# plotting
plt.plot(best_loss_history, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ------------------------------------------------
#
# Learning Rate: 0.1, Epoch Count: 50
#
# ------------------------------------------------
#
# Fold Train Loss: 0.0336, Fold Val Loss: 0.1619
# Fold Train Loss: 0.0312, Fold Val Loss: 0.2396
# Fold Train Loss: 0.0328, Fold Val Loss: 0.1100
# Fold Train Loss: 0.0306, Fold Val Loss: 0.1524
# Fold Train Loss: 0.0325, Fold Val Loss: 0.1425
# Avg Train Loss: 0.0321, Avg Val Loss: 0.1613
#
# ------------------------------------------------
#
# Learning Rate: 0.1, Epoch Count: 200
#
# ------------------------------------------------
#
# Fold Train Loss: 0.0181, Fold Val Loss: 0.2121
# Fold Train Loss: 0.0170, Fold Val Loss: 0.3217
# Fold Train Loss: 0.0175, Fold Val Loss: 0.1432
# Fold Train Loss: 0.0161, Fold Val Loss: 0.1921
# Fold Train Loss: 0.0173, Fold Val Loss: 0.1792
# Avg Train Loss: 0.0172, Avg Val Loss: 0.2097
#
# ------------------------------------------------
#
# Learning Rate: 0.1, Epoch Count: 500
#
# ------------------------------------------------
#
# Fold Train Loss: 0.0133, Fold Val Loss: 0.2587
# Fold Train Loss: 0.0128, Fold Val Loss: 0.3881
# Fold Train Loss: 0.0131, Fold Val Loss: 0.1827
# Fold Train Loss: 0.0121, Fold Val Loss: 0.2258
# Fold Train Loss: 0.0127, Fold Val Loss: 0.2177
# Avg Train Loss: 0.0128, Avg Val Loss: 0.2546
#
# ------------------------------------------------
#
# Learning Rate: 0.01, Epoch Count: 50
#
# ------------------------------------------------
#
# Fold Train Loss: 0.1002, Fold Val Loss: 0.1564
# Fold Train Loss: 0.0947, Fold Val Loss: 0.1906
# Fold Train Loss: 0.1016, Fold Val Loss: 0.1297
# Fold Train Loss: 0.0992, Fold Val Loss: 0.1475
# Fold Train Loss: 0.0992, Fold Val Loss: 0.1499
# Avg Train Loss: 0.0990, Avg Val Loss: 0.1548
#
# ------------------------------------------------
#
# Learning Rate: 0.01, Epoch Count: 200
#
# ------------------------------------------------
#
# Fold Train Loss: 0.0531, Fold Val Loss: 0.1478
# Fold Train Loss: 0.0495, Fold Val Loss: 0.2046
# Fold Train Loss: 0.0530, Fold Val Loss: 0.1079
# Fold Train Loss: 0.0505, Fold Val Loss: 0.1392
# Fold Train Loss: 0.0522, Fold Val Loss: 0.1357
# Avg Train Loss: 0.0517, Avg Val Loss: 0.1471
#
# ------------------------------------------------
#
# Learning Rate: 0.01, Epoch Count: 500
#
# ------------------------------------------------
#
# Fold Train Loss: 0.0340, Fold Val Loss: 0.1620
# Fold Train Loss: 0.0315, Fold Val Loss: 0.2378
# Fold Train Loss: 0.0332, Fold Val Loss: 0.1102
# Fold Train Loss: 0.0311, Fold Val Loss: 0.1511
# Fold Train Loss: 0.0330, Fold Val Loss: 0.1425
# Avg Train Loss: 0.0326, Avg Val Loss: 0.1607
#
# ------------------------------------------------
#
# Learning Rate: 0.001, Epoch Count: 50
#
# ------------------------------------------------
#
# Fold Train Loss: 0.2268, Fold Val Loss: 0.2476
# Fold Train Loss: 0.2239, Fold Val Loss: 0.2566
# Fold Train Loss: 0.2291, Fold Val Loss: 0.2379
# Fold Train Loss: 0.2281, Fold Val Loss: 0.2430
# Fold Train Loss: 0.2274, Fold Val Loss: 0.2386
# Avg Train Loss: 0.2271, Avg Val Loss: 0.2447
#
# ------------------------------------------------
#
# Learning Rate: 0.001, Epoch Count: 200
#
# ------------------------------------------------
#
# Fold Train Loss: 0.1425, Fold Val Loss: 0.1805
# Fold Train Loss: 0.1372, Fold Val Loss: 0.2026
# Fold Train Loss: 0.1450, Fold Val Loss: 0.1600
# Fold Train Loss: 0.1431, Fold Val Loss: 0.1718
# Fold Train Loss: 0.1415, Fold Val Loss: 0.1733
# Avg Train Loss: 0.1419, Avg Val Loss: 0.1776
#
# ------------------------------------------------
#
# Learning Rate: 0.001, Epoch Count: 500
#
# ------------------------------------------------
#
# Fold Train Loss: 0.1004, Fold Val Loss: 0.1566
# Fold Train Loss: 0.0949, Fold Val Loss: 0.1903
# Fold Train Loss: 0.1018, Fold Val Loss: 0.1299
# Fold Train Loss: 0.0995, Fold Val Loss: 0.1475
# Fold Train Loss: 0.0994, Fold Val Loss: 0.1502
# Avg Train Loss: 0.0992, Avg Val Loss: 0.1549
#
#
# ------------------------------------------------
# Learning Rate: 0.1, Number of Epochs: 50, Avg Train Loss: 0.032149309553095806, Avg Val Loss: 0.1613038452051442
# Learning Rate: 0.1, Number of Epochs: 200, Avg Train Loss: 0.0171975054833095, Avg Val Loss: 0.20965479880605256
# Learning Rate: 0.1, Number of Epochs: 500, Avg Train Loss: 0.012818736771226382, Avg Val Loss: 0.2545989844660278
# Learning Rate: 0.01, Number of Epochs: 50, Avg Train Loss: 0.09898280075208336, Avg Val Loss: 0.15481983203149063
# Learning Rate: 0.01, Number of Epochs: 200, Avg Train Loss: 0.051651259855215514, Avg Val Loss: 0.14705545399966075
# Learning Rate: 0.01, Number of Epochs: 500, Avg Train Loss: 0.0325518483982153, Avg Val Loss: 0.1607050315115174
# Learning Rate: 0.001, Number of Epochs: 50, Avg Train Loss: 0.22707944057216417, Avg Val Loss: 0.2447242227532822
# Learning Rate: 0.001, Number of Epochs: 200, Avg Train Loss: 0.14185105107578375, Avg Val Loss: 0.17764702788372846
# Learning Rate: 0.001, Number of Epochs: 500, Avg Train Loss: 0.09917377715656026, Avg Val Loss: 0.15487569051935984
# ------------------------------------------------
#
# Best Validation Loss: 0.14705545399966075, Best Training Loss: 0.051651259855215514 with Learning Rate: 0.01, Number of Epochs: 200
#
# ------------------------------------------------
